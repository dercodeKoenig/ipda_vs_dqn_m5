# %%
import pickle 
import os
from tqdm import tqdm
from collections import deque
import pandas as pd
import numpy as np

# %%
def Load(file):
    f = open(file, "rb")
    obj = pickle.load(f)
    f.close()
    return obj

# %%
def Save(_object, file):
    filehandler = open(file, 'wb') 
    pickle.dump(_object, filehandler)

# %%
data_dir = "./data"
target_dir = "./archive"
files = [data_dir+"/"+x for x in os.listdir(data_dir) if "_m5.csv" in x]
print(files)
# Out:
# ['./data/AUDJPY.csv_m5.csv', './data/AUDUSD.csv_m5.csv', './data/CHFJPY.csv_m5.csv', './data/EURAUD.csv_m5.csv', './data/EURCHF.csv_m5.csv', './data/EURGBP.csv_m5.csv', './data/EURJPY.csv_m5.csv', './data/eurusd.csv_m5.csv']

# %%
class candle_class:
    def __init__(self, o,h,l,c,t):
        self.o=o
        self.h=h
        self.l=l
        self.c=c
        self.t=t

# %%
for file in files:
    print(file)
    data = pd.read_csv(file)
    
    candles = []
    mean_o = deque(maxlen = 100)
    mean_h = deque(maxlen = 100)
    mean_l = deque(maxlen = 100)
    mean_c = deque(maxlen = 100)
    for i in tqdm(range(len(data))):
            d = data.iloc[i]
            t = d[1].split(" ")[1]
            x = candle_class(float(d[2]), float(d[3]), float(d[4]), float(d[5]), t)
            
            meano = np.mean(mean_o)
            max_off_open = meano * 2
            min_off_open = meano / 2
            
            meanh = np.mean(mean_h)
            max_off_high = meanh * 2
            min_off_high = meanh / 2
            
            meanl = np.mean(mean_l)
            max_off_low = meanl * 2
            min_off_low = meanl / 2
            
            meanc = np.mean(mean_c)
            max_off_close = meanc * 2
            min_off_close = meanc / 2
            
            if x.o > max_off_open or x.o < min_off_open:
                print("candle open error")
                continue
            if x.h > max_off_high or x.h < min_off_high:
                print("candle high error")
                continue
            if x.l > max_off_low or x.l < min_off_low:
                print("candle low error")
                continue
            if x.c > max_off_close or x.c < min_off_close:
                print("candle close error")
                continue
            
            candles.append(x)
            mean_c.append(x.c)
            mean_h.append(x.h)
            mean_l.append(x.l)
            mean_o.append(x.o)
            
    new_path = target_dir+"/"+file.split("/")[-1]
    Save(candles, new_path+"_candle_classes")
# Out:
# ./data/AUDJPY.csv_m5.csv
#   0%|                                                                                      | 0/1434598 [00:00<?, ?it/s]c:\users\root\appdata\local\programs\python\python36\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# c:\users\root\appdata\local\programs\python\python36\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  14%|█████████▋                                                             | 194924/1434598 [01:14<07:50, 2634.51it/s]
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
#  14%|█████████▋                                                             | 195452/1434598 [01:15<08:03, 2560.42it/s]
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
#  14%|█████████▋                                                             | 195710/1434598 [01:15<08:58, 2299.02it/s]
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
#  14%|█████████▋                                                             | 196175/1434598 [01:15<09:32, 2161.38it/s]
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
#  14%|█████████▋                                                             | 196607/1434598 [01:15<09:48, 2103.17it/s]
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
#  14%|█████████▋                                                             | 196819/1434598 [01:15<10:19, 1996.54it/s]
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
#  14%|█████████▊                                                             | 197229/1434598 [01:15<10:12, 2021.40it/s]
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
#  14%|█████████▊                                                             | 197675/1434598 [01:16<10:04, 2045.93it/s]
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle low error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle open error
# candle low error
# candle low error
# candle open error
# candle open error
# candle low error
# candle open error
# candle open error
# candle open error
#  18%|████████████▉                                                          | 261761/1434598 [01:40<07:06, 2747.57it/s]

# %%
import matplotlib.pyplot as plt

# %%
x = pd.read_csv(files[0])
plt.plot(x["Close"])

# %%
x = Load(target_dir+"/"+files[0].split("/")[-1]+"_candle_classes")
import matplotlib.pyplot as plt
plt.plot([i.c for i in x])
